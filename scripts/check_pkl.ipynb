# %%
import pickle

file = '../dataset/customized_dataset/test/test_00000.pkl'
with open(file, 'rb') as f:
    data = pickle.load(f)
data.keys()
# Out:
# dict_keys(['keypoints', 'scores', 'w_h', 'num_frames', 'fps', 'video_info', 'preprocessing_info', 'statistics'])

# %%
for key in list(data.keys()):
    print(key)
    try:
        print(data[key].shape)
    except AttributeError:
        print(data[key])
# Out:
# keypoints
# (174, 1, 133, 2)
# scores
# (174, 1, 133)
# w_h
# [256, 256]
# num_frames
# 174
# fps
# 25.0
# video_info
# {'source_path': '/home/chatsign/project/unisign/dataset/rgb_format/test_00000.mp4', 'original_fps': 25.0, 'total_frames': 174, 'resolution': '256x256', 'duration_seconds': 6.96}
# preprocessing_info
# {'backend': 'onnxruntime', 'device': 'cuda', 'mode': 'lightweight', 'batch_size': 512, 'normalization': 'coordinates_0_to_1', 'temporal_smoothing': True, 'confidence_threshold': 0.3, 'export_time': '2025-09-26T18:17:42.194860', 'version': '1.0.0'}
# statistics
# {'total_frames': 285, 'processed_frames': 44, 'processing_time': 30.15801453590393, 'avg_fps': 5.769610588682763, 'failures': 0}

# %%
data['keypoints'][0][0]
# Out:
# array([[0.49968892, 0.45385355],
#        [0.51915514, 0.43655023],
#        [0.4867114 , 0.4376317 ],
#        [0.5526803 , 0.4495277 ],
#        [0.47373393, 0.45060918],
#        [0.5905313 , 0.5533476 ],
#        [0.45102334, 0.5479403 ],
#        [0.61973065, 0.69609994],
#        [0.37856573, 0.6614933 ],
#        [0.55484325, 0.6409456 ],
#        [0.41857964, 0.5771396 ],
#        [0.56673926, 0.7620688 ],
#        [0.45643064, 0.75558007],
#        [0.57647234, 0.618235  ],
#        [0.4326386 , 0.62688667],
#        [0.5332141 , 0.5760582 ],
#        [0.46832666, 0.6139092 ],
#        [0.46616375, 0.606339  ],
#        [0.42290547, 0.8626443 ],
#        [0.57971674, 0.8626443 ],
#        [0.5321326 , 0.55442905],
#        [0.42290547, 0.55010325],
#        [0.43047565, 0.769639  ],
#        [0.4748154 , 0.43871313],
#        [0.4748154 , 0.4495277 ],
#        [0.47589687, 0.4603423 ],
#        [0.47914124, 0.4722383 ],
#        [0.4823856 , 0.48088998],
# ...
